# %% [markdown]
# 2장. VS Code에서 시작하는 데이터 분석 환경
# LLM 기반 데이터 분석 실무 입문 과정의 환경 점검용 실습 노트북입니다.
#
# 학습 목표
# 현재 Notebook이 사용하는 Python 환경과 작업 폴더를 확인합니다.
# 제공된 샘플 데이터를 불러와 기본 구조를 확인합니다.
# 오류 메시지와 실행 환경을 안전하게 정리해 LLM에 질문하는 방법을 익힙니다.
# 1. 실행 환경 확인
# 먼저 현재 Notebook 커널과 작업 폴더를 확인합니다. VS Code에서 프로젝트의 .venv 커널을 선택한 뒤 실행하세요.

# %%
from pathlib import Path
import sys

print('Python 실행 파일:', sys.executable)
print('현재 작업 폴더:', Path.cwd())
# Out:
# Python 실행 파일: c:\dev\llm_data_analysis-course\.venv\Scripts\python.exe
# 현재 작업 폴더: c:\dev\llm_data_analysis-course\notebooks\notebooks

# %% [markdown]
# 2. 패키지와 데이터 경로 설정
# Notebook의 현재 작업 폴더가 프로젝트 루트인지 notebooks 폴더인지에 따라 상대 경로가 달라질 수 있습니다. 아래 코드는 두 경우를 모두 확인해 데이터 폴더를 선택합니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'data' / 'raw').exists() and (PROJECT_ROOT.parent / 'data' / 'raw').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / 'data' / 'raw'
sns.set_theme(style='whitegrid')

print('프로젝트 루트:', PROJECT_ROOT)
print('데이터 폴더:', DATA_DIR)
print('데이터 폴더 존재 여부:', DATA_DIR.exists())
# Out:
# 프로젝트 루트: c:\dev\llm_data_analysis-course\notebooks\notebooks
# 데이터 폴더: c:\dev\llm_data_analysis-course\notebooks\notebooks\data\raw
# 데이터 폴더 존재 여부: False

# %% [markdown]
# 3. 샘플 데이터 불러오기
# customers.csv가 없다면 프로젝트 루트의 터미널에서 python scripts/generate_sample_data.py를 먼저 실행하세요.

# %%
customers_path = DATA_DIR / 'customers.csv'

if not customers_path.exists():
    raise FileNotFoundError(
        f'{customers_path} 파일이 없습니다. '
        '프로젝트 루트에서 python scripts/generate_sample_data.py를 실행하세요.'
    )

customers = pd.read_csv(customers_path)
customers.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 customers_path = DATA_DIR / 'customers.csv'
#       2
#       3 if not customers_path.exists():
# ----> 4     raise FileNotFoundError(
#       5         f'{customers_path} 파일이 없습니다. '
#       6         '프로젝트 루트에서 python scripts/generate_sample_data.py를 실행하세요.'
#       7     )
#
# FileNotFoundError: c:\dev\llm_data_analysis-course\notebooks\notebooks\data\raw\customers.csv 파일이 없습니다. 프로젝트 루트에서 python scripts/generate_sample_data.py를 실행하세요.
