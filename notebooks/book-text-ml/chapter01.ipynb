# %%
products = [
    {"name" : "키보드", "price":45000, "stock":12, "category":"전자기기"},
    {"name" : "마우스", "price":45000, "stock":0, "category":"전자기기"},
    {"name" : "모니터", "price":45000, "stock":4, "category":"전자기기"},
    {"name" : "책상", "price":45000, "stock":0, "category":"가구"},
    {"name" : "의자", "price":45000, "stock":7, "category":"가구"},
    {"name" : "키보드", "price":45000, "stock":12, "category":"전자기기"},
    {"name" : "마우스", "price":45000, "stock":1, "category":"전자기기"},
    {"name" : "의자", "price":45000, "stock":2, "category":"전자기기"},
]

products
# Out:
# [{'name': '키보드', 'price': 45000, 'stock': 12, 'category': '전자기기'},
#  {'name': '마우스', 'price': 45000, 'stock': 0, 'category': '전자기기'},
#  {'name': '모니터', 'price': 45000, 'stock': 4, 'category': '전자기기'},
#  {'name': '책상', 'price': 45000, 'stock': 0, 'category': '가구'},
#  {'name': '의자', 'price': 45000, 'stock': 7, 'category': '가구'},
#  {'name': '키보드', 'price': 45000, 'stock': 12, 'category': '전자기기'},
#  {'name': '마우스', 'price': 45000, 'stock': 1, 'category': '전자기기'},
#  {'name': '의자', 'price': 45000, 'stock': 2, 'category': '전자기기'}]

# %%
for_sales=[]
found = False

for product in products:
    if product["stock"] >= 1:
        found = False
        for sale in for_sales:
            if sale["name"] == product["name"]:
                sale["stock"] += product["stock"]
                found = True
                break

        if not found:
            for_sales.append(product)

for_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       4 for product in products:
#       5     if product["stock"] >= 1:
#       6         found = False
#       7         for for_sales in for_sales:
# ----> 8             if sale["name"] == product["name"]:
#       9                 sale["stock"] += product["stock"]
#      10                 found = True
#      11                 break
#
# NameError: name 'sale' is not defined
