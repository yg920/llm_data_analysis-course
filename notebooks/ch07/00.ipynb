# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# 현재 실행 위치 확인
PROJECT_ROOT = Path.cwd().resolve()

# 현재 위치에 data/raw가 없으면 상위 폴더를 계속 탐색
while not (PROJECT_ROOT / "data" / "raw").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise FileNotFoundError("data/raw 폴더를 찾을 수 없습니다.")
    
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR = PROJECT_ROOT / "data" / "raw"

print("프로젝트 루트:", PROJECT_ROOT)
print("데이터 폴더:", DATA_DIR)
print("데이터 폴더 존재 여부:", DATA_DIR.exists())

customers = pd.read_csv(DATA_DIR / "customers.csv")
order_items = pd.read_csv(DATA_DIR / "order_items.csv")
orders = pd.read_csv(DATA_DIR / "orders.csv")
products = pd.read_csv(DATA_DIR / "products.csv")

print("customers:", customers.shape)
print("order_items:", order_items.shape)
print("orders:", orders.shape)
print("products:", products.shape)
# Out:
# 프로젝트 루트: C:\dev\llm_data_analysis-course
# 데이터 폴더: C:\dev\llm_data_analysis-course\data\raw
# 데이터 폴더 존재 여부: True
# customers: (150, 6)
# order_items: (764, 5)
# orders: (300, 5)
# products: (100, 4)

# %%
from pathlib import Path
import sys

# 현재 위치에서 프로젝트 루트 찾기
PROJECT_ROOT = Path.cwd().resolve()

while not (PROJECT_ROOT / "src").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise FileNotFoundError("src 폴더를 찾을 수 없습니다.")
    PROJECT_ROOT = PROJECT_ROOT.parent

# Python이 프로젝트 루트를 찾을 수 있도록 경로 추가
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print("프로젝트 루트:", PROJECT_ROOT)
print("src 존재 여부:", (PROJECT_ROOT / "src").exists())
# Out:
# 프로젝트 루트: C:\dev\llm_data_analysis-course
# src 존재 여부: True

# %%
from pathlib import Path

print("PROJECT_ROOT:", PROJECT_ROOT)
print("src 폴더:", PROJECT_ROOT / "src")

for file in (PROJECT_ROOT / "src").iterdir():
    print(file.name)
# Out:
# PROJECT_ROOT: C:\dev\llm_data_analysis-course
# src 폴더: C:\dev\llm_data_analysis-course\src
# app.py
# midterm_project.py
# preprocessing.py
# titanic_app
# __pycache__

# %%
import pandas as pd
import numpy as np

customers = pd.read_csv("../../data/raw/customers.csv")
order_items = pd.read_csv("../../data/raw/order_items.csv")
orders = pd.read_csv("../../data/raw/orders.csv")
products = pd.read_csv("../../data/raw/products.csv")

customers.info()
order_items.info()
orders.info()
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  150 non-null    int64
#  1   name         150 non-null    str
#  2   gender       150 non-null    str
#  3   age          150 non-null    int64
#  4   city         150 non-null    str
#  5   signup_date  150 non-null    str
# dtypes: int64(2), str(4)
# memory usage: 11.0 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  764 non-null    int64
#  1   order_id       764 non-null    int64
#  2   product_id     764 non-null    int64
#  3   quantity       764 non-null    int64
#  4   unit_price     764 non-null    int64
# dtypes: int64(5)
# memory usage: 30.0 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# ...

# %%
from matplotlib import font_manager
installed_fonts = {font.name for font in font_manager.fontManager.ttflist}
font_candidates = ["Malgun Gothic", "AppleGothic", "Apple SD Gothic Neo", "Nato Sans CJK KR", "NanumGothic"]

# %%
korean_font = next(
    (name for name in font_candidates if name in installed_fonts), None
)

print("선택된 한글 폰트 : ", korean_font)

if korean_font:
    plt.rcParams["font.family"] = korean_font
plt.rcParams["axes.unicode_minus"] = False
# Out:
# 선택된 한글 폰트 :  Malgun Gothic

# %%
from src.visualization import setup_korean_font

setup_korean_font()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from src.visualization import setup_korean_font
#       2
#       3 setup_korean_font()
#
# ModuleNotFoundError: No module named 'src.visualization'

# %%
x_data = ["korean", "영어", "수학", "과학", "도덕"]
y_data = [75, 70, 87, 88, 59]

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x_data, y_data)
ax.set_title("그래프 제목")
ax.set_xlabel("x축")
ax.set_ylabel("y축")
ax.set_ylim(bottom=0)
fig.tight_layout()
fig.savefig(
    "graph.png",
    dpi=150,
    bbox_inches="tight",
)
plt.show()

# %%
from pathlib import Path
import pandas as pd

# 프로젝트 루트 찾기
PROJECT_ROOT = Path.cwd().resolve()

while not (PROJECT_ROOT / "data" / "processed").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise FileNotFoundError("data/processed 폴더를 찾을 수 없습니다.")
    PROJECT_ROOT = PROJECT_ROOT.parent

PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"

# CSV 불러오기
customers_cleaned = pd.read_csv(PROCESSED_DIR / "customers_clean.csv")
order_items_cleaned = pd.read_csv(PROCESSED_DIR / "order_items_clean.csv")
orders_cleaned = pd.read_csv(PROCESSED_DIR / "orders_clean.csv")
products_cleaned = pd.read_csv(PROCESSED_DIR / "products_clean.csv")
visualization = pd.read_csv(PROCESSED_DIR / "visualization.csv")

# 확인
print("customers:", customers_cleaned.shape)
print("order_items:", order_items_cleaned.shape)
print("orders:", orders_cleaned.shape)
print("products:", products_cleaned.shape)
print("visualization:", visualization.shape)
# Out:
# customers: (150, 6)
# order_items: (752, 6)
# orders: (300, 7)
# products: (96, 4)
# visualization: (752, 23)

# %%
orders["order_date"] = pd.to_datetime(
    orders["order_date"],
    errors="raise"
)

orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        300 non-null    int64
#  1   customer_id     300 non-null    int64
#  2   order_date      300 non-null    datetime64[us]
#  3   payment_method  300 non-null    str
#  4   order_status    300 non-null    str
# dtypes: datetime64[us](1), int64(2), str(2)
# memory usage: 17.0 KB

# %%
products_cleaned.head()
# Out:
#    product_id product_name category     price
# 0           1    도서 상품 001       도서   61000.0
# 1           2  전자기기 상품 002     전자기기  154000.0
# 2           3    뷰티 상품 003     전자기기   48000.0
# 3           4    패션 상품 004       패션   33000.0
# 4           5   스포츠 상품 005      스포츠   73000.0

# %%
df_visualization = pd.read_csv(PROCESSED_DIR / "visualization.csv")

df_visualization.head()
# Out:
#    order_item_id  order_id  customer_id  product_id  order_date order_month  \
# 0              1         1        144.0          39  2026-07-12     2026-07
# 1              2         2        149.0          26  2025-10-02     2025-10
# 2              3         2        149.0          46  2025-10-02     2025-10
# 3              4         2        149.0          80  2025-10-02     2025-10
# 4              5         2        149.0          91  2025-10-02     2025-10
#
#   order_dayofweek payment_method order_status gender  ...  product_name  \
# 0          Sunday      naver_pay    completed      F  ...     뷰티 상품 039
# 1        Thursday      kakao_pay    completed      M  ...     뷰티 상품 026
# 2        Thursday      kakao_pay    completed      M  ...   생활용품 상품 046
# 3        Thursday      kakao_pay    completed      M  ...     패션 상품 080
# 4        Thursday      kakao_pay    completed      M  ...   전자기기 상품 091
#
#   category     price quantity unit_price  line_total  order_match  \
# ...

# %%
category_sales = df_visualization.groupby("category", dropna=False, as_index=False).agg(
    total_amount=("line_total", sum),
    total_quantity=("quantity", sum)
).sort_values("total_amount", ascending=False)

category_sales
# Out:
#   category  total_amount  total_quantity
# 9       패션    63322000.0           532.0
# 6       식품    45972000.0           384.0
# 8     전자기기    34218000.0           280.0
# 0       도서    27876000.0           272.0
# 2       뷰티    26467000.0           268.0
# 5      스포츠    20468000.0           253.0
# 4     생활용품    13835000.0           204.0
# 3    생활 용품     3224000.0            26.0
# 1      뷰 티     1026000.0            19.0
# 7    전자 기기      252000.0            12.0

# %%
df_visualization = df_visualization.dropna()
df_visualization.isna().sum().sum()
# Out:
# np.int64(0)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(
    df_visualization["category"],
    df_visualization["total_amount"]
)

ax.set_title("카테고리별 전체 주문 기준 금액")
ax.set_xlabel("카테고리")
ax.set_ylabel("금액")
ax.set_ylim(bottom=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\dev\llm_data_analysis-course\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
monthly_sales = df_visualization.groupby(df_visualization["order_month"], as_index=False).agg(
    total_amount = ("line_total", "sum"),
    order_count = ("order_id", "nunique")
).sort_index()

monthly_sales
# Out:
#    order_month  total_amount  order_count
# 0      2025-07    13389000.0           18
# 1      2025-08    31736000.0           24
# 2      2025-09    12278000.0           12
# 3      2025-10    16352000.0           22
# 4      2025-11    12738000.0           22
# 5      2025-12    15684000.0           23
# 6      2026-01    18132000.0           25
# 7      2026-02    13582000.0           18
# 8      2026-03    13701000.0           22
# 9      2026-04    19700000.0           24
# 10     2026-05    22665000.0           20
# 11     2026-06    14943000.0           24
# 12     2026-07     9131000.0           11
# 13     2026-08    20006000.0           21
# 14     2027-01      909000.0            1
# 15     2028-12     1714000.0            1

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(
    monthly_sales["order_month"],
    monthly_sales["total_amount"],
    marker="o",
)

ax.set_title("월별 completed 주문 기준 금액")
ax.set_xlabel("주문 월")
ax.set_ylabel("금액")
# Out:
# Text(0, 0.5, '금액')

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.hist(
    customers["age"],
    bins=100,
)

ax.set_title("고객 나이 분포")
ax.set_xlabel("고객 나이")
ax.set_ylabel("고객 수")
# Out:
# Text(0, 0.5, '고객 수')

# %%
products_quantity = df_visualization.groupby(df_visualization["product_id"], as_index=False).agg(
    total_quantity = ("quantity", "sum"),
).sort_index()

monthly_sales
# Out:
#    order_month  total_amount  order_count
# 0      2025-07    13389000.0           18
# 1      2025-08    31736000.0           24
# 2      2025-09    12278000.0           12
# 3      2025-10    16352000.0           22
# 4      2025-11    12738000.0           22
# 5      2025-12    15684000.0           23
# 6      2026-01    18132000.0           25
# 7      2026-02    13582000.0           18
# 8      2026-03    13701000.0           22
# 9      2026-04    19700000.0           24
# 10     2026-05    22665000.0           20
# 11     2026-06    14943000.0           24
# 12     2026-07     9131000.0           11
# 13     2026-08    20006000.0           21
# 14     2027-01      909000.0            1
# 15     2028-12     1714000.0            1

# %%
product_sales = df_visualization.groupby("product_id", as_index=False).agg(
    total_quantity = ("quantity", "sum"),
    total_amount = ("line_total", sum)
).sort_index()

products_sales
# Out:
#     product_id  total_quantity  total_amount
# 0            1            20.0     1220000.0
# 1            2            19.0     2926000.0
# 2            3             7.0      336000.0
# 3            4            23.0      759000.0
# 4            5            24.0     1752000.0
# ..         ...             ...           ...
# 91          96            75.0     7200000.0
# 92          97            31.0     5797000.0
# 93          98            25.0      800000.0
# 94          99            18.0     3366000.0
# 95         100            21.0      714000.0
#
# [96 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.scatter(
    product_sales["total_amount"],
    product_sales["total_quantity"],
    alpha=0.6,
)

ax.set_title("상품 가격과 completed 판매 수량")
ax.set_xlabel("상품 가격")
ax.set_ylabel("completed 판매 수량")
# Out:
# Text(0, 0.5, 'completed 판매 수량')

# %%
customer_sales = (
    df_visualization
    .groupby("customer_id", dropna=False, as_index=False)
    .agg(
        total_amount=("line_total", "sum"),
        order_count=("order_id", "nunique")
    )
    .sort_values("total_amount", ascending=False)
)

customer_sales.head()
# Out:
#     customer_id  total_amount  order_count
# 15         18.0    16666000.0            2
# 2           3.0     8909000.0            7
# 17         20.0     6200000.0            6
# 45         52.0     5388000.0            5
# 11         14.0     5122000.0            4

# %%
top_customers = customer_sales.head(10).reset_index(drop=True)

print(top_customers)
# Out:
#    customer_id  total_amount  order_count
# 0         18.0    16666000.0            2
# 1          3.0     8909000.0            7
# 2         20.0     6200000.0            6
# 3         52.0     5388000.0            5
# 4         14.0     5122000.0            4
# 5         55.0     4850000.0            6
# 6         90.0     4847000.0            5
# 7         22.0     4667000.0            4
# 8         15.0     4281000.0            5
# 9        115.0     3988000.0            4
